# %%
from exec_3_dataset_model_generator import *
import time

# %%
while(True):
    time.sleep(300)
    execute()
# Out:
# Deleting files #30
# e017a1cc8be345a48191171e97e7e1ec
# b75ca78d1bd64732b65e4334dbbc6d3f
# 5d691e498f144a9594f53dff320ad945
# 18b6d71b344d428da6e74f3836885833
# 18f8f3efbad744bf9d078845ef3cc1d5
# b8d0b3e5c740483bb839265a07c4ffa1
# f0ac76867dab45bb9937a0772c44e186
# d89d6770a922466987ea911c93481f0f
# 7d70985c3e4f41e4b04c3088bf7d5416
# 4ff8e870f3a4411ba3f36c4b3073daa9
# 5d05b632fae042b69f1213159b4f78ad
# eb1471ce435d4ae1a70b1d3f75a1f272
# dda418b5efbb40e5ab36dc9e1f6363b8
# 99d4feef38194b2fb91d2209b5f65ce1
# 7fb4613655684042b095b7f43714c9ea
# c39fcb7aadf2452fa6128359b76b5c9d
# ee64b1d2a73a4209baf3a9234d633f08
# 0e0e662a56ef47a6884058ce16a59bb1
# f184eea312c44331b13170ccc34b1fa7
# adfc752837584cbcb55f3df3ffa752fc
# 0b619c14f2354b70abf441495285b88a
# b370c414b37144b9a1c83615123d88da
# e2ea158a2c444b7da348fdf08f2afd60
# ca66360375b349ecb4520ed44008de42
# af0c32d3219749b08124970a9a4ad34e
# c67ee0b8e0844cfaa08a6151b6bafccf
# e3baef7d288c4d8eb6e073511c40d86e
# ...
