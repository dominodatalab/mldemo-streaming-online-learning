# %%
from exec_3_dataset_model_generator import *

# %%
execute()
# Out:
# Deleting files #200
# b919646cc2fd4028bb7da0a31485b201
# d8a7bd452498437d94770a95e2d4e98e
# 922d18c7ccf1458d9b888518ee0a71f0
# 0d7f605386304709a5f2faa252c5e556
# 6c6264e7ef254b509ddc9a1d55f6d83d
# d5bcc70ff51d49d39f130c3c4fda539b
# d23d363226c34f2192c9504b30ad7dcb
# 28b6cb7800a74e11826020236fda3651
# bcc6be371a814a52a9ddf971d06ae8de
# f8f6606a942843db910389cff4aa25fe
# 229b75aa27a9445fb59c3ad43f6d777f
# 54fb8d20c3294cb6aa7666d9585703d9
# 85513d24e5ae43bb999e2be78733c175
# 758aa63d623a4344a44427e0e1846159
# e025f49674d142e293306d5b8f29215e
# 016a60c60799418e9cdfcda287e4af6a
# 666004194817401c9f21f08eb998579f
# 02fe71c7bb6042659aa846ae7d8a3929
# ae20ea84d5c9411c8a8af1a8e2fd2e5a
# afd34db355fa41498e04177b941ea668
# 2764d4e9aed14b50af63374ddf2d12ca
# e3a3ea12d0b24c80a7233e47d7bb81d0
# 930d1e1972304144b2f07d4e221b51a3
# ba59ef80f1fd4cf091671cd95f559f28
# fc12ebb75b884ceca71cfd99a4b493ba
# 446979ae33ac463a96125f0feea98790
# 46cae14e5b5f4f6f8defd135056efd0a
# ...
